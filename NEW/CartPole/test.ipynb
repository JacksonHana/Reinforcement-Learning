# %%
# !pip install stable-baselines3[extra]
# !pip install pyglet==1.5.27
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Admin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Admin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
environment_name
# Out:
# 'CartPole-v0'

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info= env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# env.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 10
#       8     env.render()
#       9     action = env.action_space.sample()
# ---> 10     n_state, reward, done, info= env.step(action)
#      11     score += reward
#      12 print('Episode:{} Score:{}'.format(episode, score))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:55, in DummyVecEnv.step_wait(self)
# ...

# %%
env.close()

# %% [markdown]
# ### Observation Space
#     The observation is a `ndarray` with shape `(4,)` with the values corresponding to the following positions and velocities:
#     | Num | Observation           | Min                 | Max               |
#     |-----|-----------------------|---------------------|-------------------|
#     | 0   | Cart Position         | -4.8                | 4.8               |
#     | 1   | Cart Velocity         | -Inf                | Inf               |
#     | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
#     | 3   | Pole Angular Velocity | -Inf                | Inf               |

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.reset()
# Out:
# array([0.01936995, 0.0394152 , 0.00045519, 0.04801906], dtype=float32)

# %% [markdown]
# ### Action Space
#     The action is a `ndarray` with shape `(1,)` which can take values `{0, 1}` indicating the direction
#      of the fixed force the cart is pushed with.
#     | Num | Action                 |
#     |-----|------------------------|
#     | 0   | Push cart to the left  |
#     | 1   | Push cart to the right |

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# # Train RL Model

# %%
log_path = os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda :env])    # wrapping in vetor
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
PPO?? # go ionside the algorithms
# Out:
#   Cell In[16], line 1
#     PPO?? # go ionside the algorithms
#        ^
# SyntaxError: invalid syntax

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 2274 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1544      |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0101997 |
# |    clip_fraction        | 0.111     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.686    |
# |    explained_variance   | -0.00212  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.91      |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.0166   |
# |    value_loss           | 50.4      |
# ...

# %% [markdown]
# # Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'Saved_Models', 'PPO_Model_CartPole')

# %%
model.save(PPO_Path)    #save model

# %%
model = PPO.load(PPO_Path, env=env) #load model
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Evaluation
# test how well agent performing, if the average score is 200 or higher, it considered solved

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True) # test 10 episode
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # Test Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action,_ = model.predict(obs) #using model
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode,score))
# Out:
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [200.]
# Episode: 5 Score: [200.]

# %%
env.close()

# %%
# Test
env = gym.make(environment_name)
env = DummyVecEnv([lambda :env])    # wrapping in vetor
model1 = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model1.learn(total_timesteps=200)
# Out:
# Logging to Training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 2202 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
PPO_Path = os.path.join('Training', 'Saved_Models', 'PPO_Model1_CartPole')

# %%
model1.save(PPO_Path)    #save model

# %%
model1 = PPO.load(PPO_Path, env=env) #load model

# %%
evaluate_policy(model1, env, n_eval_episodes=10, render=True) # test 10 episode
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action,_ = model.predict(obs) #using model
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode,score))
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 episodes = 5
#       2 for episode in range(1, episodes+1):
# ----> 3     obs = env.reset()
#       4     done = False
#       5     score = 0
#
# NameError: name 'env' is not defined

# %%
# Test
env = gym.make(environment_name)
env = DummyVecEnv([lambda :env])    # wrapping in vetor
model2 = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model2.learn(total_timesteps=20000)
PPO_Path = os.path.join('Training', 'Saved_Models', 'PPO_Model2_CartPole')
# model2.save(PPO_Path)    #save model
# model2 = PPO.load(PPO_Path, env=env) #load model
# Out:
# Using cpu device
# Logging to Training\Logs\PPO_13
# -----------------------------
# | time/              |      |
# |    fps             | 2052 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1465        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007917541 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00201     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.92        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0148     |
# ...

# %%
model2.save(PPO_Path)    #save model
model2 = PPO.load(PPO_Path, env=env) #load model

# %%
evaluate_policy(model2, env, n_eval_episodes=10, render=True) # test 10 episode
# Out:
# (200.0, 0.0)

# %%
env.close()

# %%
model = PPO.load(PPO_Path, env=env) #load model

# %%
evaluate_policy(model2, env, n_eval_episodes=10, render=True) # test 10 episode
# Out:
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # View Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_2'

# %% [markdown]
# # Callback training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved_Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose = 1 )

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_14
# -----------------------------
# | time/              |      |
# |    fps             | 373  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008805221 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000226   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0148     |
# ...

# %% [markdown]
# # Changing Policy
# for using a different neural network

# %%
net_arch = [dict(pi=[128,128,128,128], vf = [128,128,128,128])] # having 128 units in each layer, 4 layers, same as value funtion

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\policies.py:457: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_15
# -----------------------------
# | time/              |      |
# |    fps             | 1319 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 996         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013595126 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0254     |
# ...

# %% [markdown]
# # Changing Algorithms

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2510     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4069     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 185      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4988     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 252      |
# ...

# %% [markdown]
# # TESTING NEW MODEL AND NEW SAVE

# %%
log_path = os.path.join('Training','Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda :env])    # wrapping in vetor
test = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
test.learn(total_timesteps=2000)
# Out:
# Logging to Training\Logs\PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 2239 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
PPO_Path = os.path.join('Training', 'PPO_CartPole_Test')

# %%
PPO_Path
# Out:
# 'Training\\PPO_CartPole_Test'

# %%
test.save(PPO_Path)  #save model

# %%
test = PPO.load(PPO_Path, env=env) #load model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action,_ = model.predict(obs) #using model
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode,score))
env.close()
# Out:
# Episode: 1 Score: [18.]
# Episode: 2 Score: [52.]
# Episode: 3 Score: [16.]
# Episode: 4 Score: [35.]
# Episode: 5 Score: [22.]
